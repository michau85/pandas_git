# %%
import pandas as pd
df=pd.read_csv('proba.csv',';')
df['adres2'] = df['adres'].apply(lambda x: x.replace("https://", ""))
df['slowo']=df['slowo'].str.lower()
df
# Out:
# D:\python_projects\python\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           slowo                   adres          adres2
# 0            wp       https://www.wp.pl       www.wp.pl
# 1            wp       https://www.wp.pl       www.wp.pl
# 2   wp consults       https://www.wp.pl       www.wp.pl
# 3          enea       https://www.wp.pl       www.wp.pl
# 4      t-mobile  https://www.tmobile.pl  www.tmobile.pl
# 5       tmobile  https://www.tmobile.pl  www.tmobile.pl
# 6            wp                      wp              wp
# 7        cos wp       https://www.wp.pl       www.wp.pl
# 8            wp  https://www.wp-made.pl  www.wp-made.pl
# 9            wp  https://www.made-wp.pl  www.made-wp.pl
# 10           wp               wpmade.pl       wpmade.pl
# 11           wp               madewp.pl       madewp.pl
# 12           wp           madewp.com.pl   madewp.com.pl

# %%
import re

def fun(company_name,url):
    result=False
    words_company_name=company_name.split(sep=' ')   
    for word in words_company_name:
        found= re.search(word, url)
        if found:
            result=True
    return result         
    
df['result']= df.apply(lambda x: fun(x.slowo,x.adres2), axis=1)
df
# Out:
#           slowo                   adres          adres2  result
# 0            wp       https://www.wp.pl       www.wp.pl    True
# 1            wp       https://www.wp.pl       www.wp.pl    True
# 2   wp consults       https://www.wp.pl       www.wp.pl    True
# 3          enea       https://www.wp.pl       www.wp.pl   False
# 4      t-mobile  https://www.tmobile.pl  www.tmobile.pl   False
# 5       tmobile  https://www.tmobile.pl  www.tmobile.pl    True
# 6            wp                      wp              wp    True
# 7        cos wp       https://www.wp.pl       www.wp.pl    True
# 8            wp  https://www.wp-made.pl  www.wp-made.pl    True
# 9            wp  https://www.made-wp.pl  www.made-wp.pl    True
# 10           wp               wpmade.pl       wpmade.pl    True
# 11           wp               madewp.pl       madewp.pl    True
# 12           wp           madewp.com.pl   madewp.com.pl    True

# %%
 s = re.search('wp', 'wp')
if s:
    print('t')
else:
    print('n')
# Out:
# t

# %%
url='www.secret-ola.pl'
a=re.findall(r"\w*secretw*",url)
a
# Out:
# ['secret']

# %%
import re
firma='secret-ola spolka z oo'
slowa=firma.split(sep=' ')
wynik=[]
url='secret'
a=re.findall(r"secret",url)
s = re.search(r"\w*secret\w*", url)

s
# Out:
# <re.Match object; span=(0, 6), match='secret'>

# %%
for slo in slowa:
    s = re.search(slo, url)
    if s:
        wynik.append('tak')
    else:
        wynik.append('nie')
        
for w in wynik:
    print(w)
