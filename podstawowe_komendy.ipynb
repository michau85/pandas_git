# %%
import pandas as pd
df=pd.read_csv('survey_results_public.csv')
#ex=pd.read_csv('pyt.csv',';')
df=pd.read_excel('plik.xlsx', sheet_name="rejestr_zakodowany")
df.set_index('Respondent', inplace=True)
df
empty = pd.DataFrame(columns=['name','age','gender'])
empty=empty.append({'name':"jan",'age':100, 'gender':'m'}, ignore_index=True)
empty=empty.append({'gender':'m'}, ignore_index=True)
empty=empty.append({'name':"fran",'age':300,'gender':'m',}, ignore_index=True)
df3.loc[war,'wiek_slownie']='piecdziesiat'

res=pd.Series([10,20,30])
cars={'audi':'a4','bmw':'x5'}
res2=pd.Series(cars)
frame={'name':["luwy",'Kuba'],
       'club':['Bay',np.NaN],
       'age':[32,np.NaN]
      }
tab=['sty','lut','mar']
seria=pd.Series(tab)
df=pd.DataFrame(frame)
df['ser']=seria
# Out:
# Traceback (most recent call last):
#
#   File D:\python_projects\python\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [2] in <cell line: 4>
#     df=pd.read_excel('plik.xlsx', sheet_name="rejestr_zakodowany")
#
#   File D:\python_projects\python\lib\site-packages\pandas\util\_decorators.py:311 in wrapper
#     return func(*args, **kwargs)
#
#   File D:\python_projects\python\lib\site-packages\pandas\io\excel\_base.py:457 in read_excel
#     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#
#   File D:\python_projects\python\lib\site-packages\pandas\io\excel\_base.py:1363 in __init__
#     if import_optional_dependency("xlrd", errors="ignore") is None:
#
#   File D:\python_projects\python\lib\site-packages\pandas\compat\_optional.py:138 in import_optional_dependency
#     module = importlib.import_module(name)
#
# ...

# %%
import pandas as pd
con=pd.Series(['Poland', 'france','poland','France','9ard'])
for k,v in wyn.iteritems():
    con[k]
    
for k,v in df.iterrows():
    if (v['brk']=='10_C10_S951_XK') & (v['bs']>2):
        df.loc[k,'nowa']='war1'

# %%
import pandas as pd

countries=['Poland','Germany']
war2=df["Country"].isin(countries)
war=df['LanguageWorkedWith'].str.contains("Python")==True
con=pd.Series(['Poland', 'france','poland','France','9ard'])
wyn=con.str.match("([a-z])")

# %%
import numpy as np
import pandas as pd

agregat=df.groupby(['s1a','s1b','s1c'])
agregat['regon'].count()
df['age'].isnull().sum()


#df['name'].str.count(pat="(^[A-Z][a-z]{3})")

# %%
df=pd.read_csv('survey_results_public.csv')
pd.set_option('max_columns', None)
res=df.Age.value_counts().to_frame().reset_index()
bi=pd.cut(res['index'],bins=[1,20,40,60], labels=['l','st','bst'])
res['prze']=bi
res
# Out:
#      index   Age prze
# 0     25.0  2693   st
# 1     28.0  2412   st
# 2     30.0  2406   st
# 3     26.0  2391   st
# 4     27.0  2338   st
# ..     ...   ...  ...
# 105   26.8     1   st
# 106    3.0     1    l
# 107   14.7     1    l
# 108   26.5     1   st
# 109   22.5     1   st
#
# [110 rows x 3 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import scale
from sklearn.preprocessing import normalize, StandardScaler
from numpy import asarray
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
# Create a DataFrame
df = pd.DataFrame({'Student Names' : ['Jenny', 'Singh', 'Charles', 'Richard', 'Veena'],
                   'Category' : ['Online', 'Offline', 'Offline', 'Offline', 'Online'],
                   'Gender' : ['Female', 'Male', 'Male', 'Male', 'Female'],
                  'Courses': ['Java', 'Spark', 'PySpark','Hadoop','C'],
                   'Fee': [150, 170, 270, 290, 120],
                   'Discount': [101, 99, 102, 98, 98]})

# Standardize columns


# Overwrite old columns with transformed columns

df['D_S'] = scale(df['Discount'])
scaler = MinMaxScaler()
caled = scaler.fit_transform([10,20])
caled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 23>()
#      21 df['D_S'] = scale(df['Discount'])
#      22 scaler = MinMaxScaler()
# ---> 23 caled = scaler.fit_transform([10,20])
#      24 caled
#
# File D:\python_projects\python\lib\site-packages\sklearn\base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
#     869     # fit method of arity 2 (supervised transformation)
#     870     return self.fit(X, y, **fit_params).transform(X)
#
# ...
